# %% [markdown]
# # RenAIssance Evaluation Notebook
# This notebook summarizes OCR/VLM experiment outputs for GSoC test submission.

# %% [markdown]
# ## Loaded Metrics Files
# - outputs\test1\metrics.test1.json
# - outputs\test2\metrics.test2.json
# - outputs\ablation_summary.json

# %% [markdown]
# ## metrics.test1.json
# ```json
# {
#   "cer_mean": 0.5265785545560855,
#   "cer_median": 0.5546134663341646,
#   "wer_mean": 7.25,
#   "wer_median": 7.25,
#   "normalized_cer_mean": 0.5,
#   "normalized_wer_mean": 7.25
# }
# ```

# %% [markdown]
# ## metrics.test2.json
# ```json
# {
#   "cer_mean": 0.8033898305084746,
#   "cer_median": 1.0,
#   "wer_mean": 11.6,
#   "wer_median": 14.5,
#   "normalized_cer_mean": 0.8,
#   "normalized_wer_mean": 11.6
# }
# ```

# %% [markdown]
# ## ablation_summary.json
# ```json
# {}
# ```

# %% [markdown]
# ## Interpretation
# - Compare CER/WER across ablations.
# - Highlight where LLM/VLM improves OCR robustness.
# - Discuss remaining failure modes (layout drift, historical spelling ambiguity).
